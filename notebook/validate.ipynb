# %%
import numpy as np
from scipy import stats
rng = np.random.default_rng()
sample1 = stats.uniform.rvs(size=100, random_state=rng)
sample2 = stats.norm.rvs(size=110, random_state=rng)
response=stats.ks_2samp(sample1, sample2)

# %%
sample1
# Out:
# array([0.34126091, 0.05671718, 0.85755738, 0.64328599, 0.06293401,
#        0.40272922, 0.47836305, 0.08639204, 0.2536428 , 0.07013727,
#        0.13526335, 0.6542698 , 0.05105211, 0.44176002, 0.19790927,
#        0.4822496 , 0.65721936, 0.55698141, 0.12004974, 0.1885385 ,
#        0.15079322, 0.96704546, 0.16136581, 0.88404033, 0.55671821,
#        0.55712692, 0.25002952, 0.99307076, 0.27496942, 0.69272401,
#        0.31767796, 0.4789675 , 0.79336035, 0.48920609, 0.69440722,
#        0.4771389 , 0.77710642, 0.01976161, 0.04658293, 0.15910874,
#        0.59690739, 0.16926976, 0.70500556, 0.24359974, 0.05336247,
#        0.88733207, 0.87325589, 0.89943844, 0.71232645, 0.48150449,
#        0.93965169, 0.6845731 , 0.28058444, 0.81687649, 0.42074227,
#        0.58280193, 0.07144425, 0.74047606, 0.51086709, 0.27939357,
#        0.72721096, 0.87201329, 0.54194669, 0.79363669, 0.68694813,
#        0.10070581, 0.63915529, 0.84743958, 0.24755721, 0.27383427,
#        0.74353087, 0.7051888 , 0.38201586, 0.66816563, 0.20173125,
#        0.95516271, 0.05930953, 0.03870779, 0.97530937, 0.58917715,
#        0.08453944, 0.62699024, 0.30056393, 0.38493326, 0.23508381,
#        0.94538705, 0.23456882, 0.82244956, 0.03445249, 0.1693904 ,
#        0.05959842, 0.5742516 , 0.42325122, 0.70479052, 0.50008623,
#        0.17442763, 0.47802899, 0.39401687, 0.12470126, 0.75758192])

# %%
sample2
# Out:
# array([-7.76106444e-01,  2.14690159e-01, -7.13244040e-01,  1.56397140e+00,
#         1.22437135e+00,  6.33602173e-01, -1.77954621e+00,  1.01226333e-01,
#        -2.13490750e+00, -1.36466124e-03,  3.92530291e-01, -1.31231640e+00,
#        -1.43905090e+00, -1.18858869e+00,  1.54288166e-01, -6.04952963e-01,
#         3.83504068e-01,  1.66151430e+00,  1.00914438e+00,  8.83416689e-01,
#        -1.74300001e+00,  1.11871145e+00, -2.10566729e+00, -6.91497351e-01,
#        -1.23558854e+00,  6.13841025e-01, -1.05550961e+00, -9.94493938e-01,
#         7.56442162e-01,  1.33182491e+00,  1.49891105e+00, -1.29977154e+00,
#        -8.48500872e-01, -4.68530305e-01,  2.02897152e-01,  7.57845632e-01,
#        -4.13684766e-01, -1.88665486e+00,  5.76673176e-01, -1.44404397e+00,
#         5.98944913e-01,  3.73205581e-01, -1.92663632e+00,  2.08503820e-01,
#        -1.10106142e-01,  1.90822089e-01, -7.26858624e-01,  2.68302283e+00,
#        -1.22184312e+00, -3.19410830e-01,  7.04255055e-01, -3.36486525e+00,
#        -2.16696328e+00, -5.91577422e-01, -8.24782088e-01, -2.02278235e+00,
#        -1.42054073e+00, -3.62659352e-01,  1.44866382e+00, -5.78037053e-01,
#         1.87223713e-01,  1.19472194e+00, -3.16946004e-01, -8.01918767e-01,
#         1.20337853e+00, -8.10787192e-01, -1.23327250e+00,  2.88957432e-01,
#        -1.44354563e+00,  1.09385425e+00, -2.78242086e-01,  1.69152655e-01,
#        -2.73470617e-01, -2.78275577e-01, -4.91280676e-01, -4.91795287e-01,
#        -5.04278627e-01, -8.29863889e-02, -9.34075919e-01, -3.24522344e-02,
#         5.31025968e-01, -5.96815566e-02,  1.81288517e+00,  6.36743162e-01,
#         1.56651655e+00,  1.08657401e+00,  3.28354142e-01,  1.60724831e-01,
#         3.80032255e-01, -6.34185589e-01,  2.01482678e+00,  2.36854634e-01,
#         1.21189674e+00,  5.02453872e-01,  2.44366791e+00, -2.86122523e-02,
#        -9.23476089e-01, -1.82016648e-01,  6.28441359e-01, -1.30965384e+00,
#         1.03250391e+00, -1.44293628e-01,  7.05130518e-01, -5.38558149e-01,
#         3.13376734e-01, -4.68524665e-01,  4.92286076e-01,  4.22850918e-01,
#         5.98036923e-01, -6.18317415e-01])

# %%
response.pvalue ## if p value  greater than 0.5 thet data have good relation or fromsame distribuction
# Out:
# 4.351893101922804e-11

# %%
round(response.pvalue)
# Out:
# 0

# %%
round(response.pvalue,10)
# Out:
# 0.0

# %%
# #Anomly in my dataset

# #1.High Null Value
# ##2.Missing columns
# #OUTLIER 
# #cATEROCIAL :
# Gender --. MALE ,FEMALE ,OTHER

# %%
import pandas as pd

# %%
df=pd.read_csv("/config/workspace/artifact/12122022__195112/data_ingestion/dataset/train.csv")

# %%
df.isnull().sum()
# Out:
# class         0
# aa_000        0
# ab_000    22338
# ac_000     1748
# ad_000     7438
#           ...
# ee_007      305
# ee_008      305
# ee_009      305
# ef_000     1412
# eg_000     1411
# Length: 171, dtype: int64

# %%
(df.isnull().sum()/df.shape[0]).values
# Out:
# array([0.        , 0.        , 0.77160622, 0.06037997, 0.25692573,
#        0.04500864, 0.04500864, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01056995, 0.01053541, 0.01053541,
#        0.07765112, 0.01067358, 0.01053541, 0.01067358, 0.00977547,
#        0.01067358, 0.00977547, 0.04873921, 0.01053541, 0.01053541,
#        0.01053541, 0.04504318, 0.04507772, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01070812, 0.01070812,
#        0.01070812, 0.01070812, 0.01070812, 0.01070812, 0.01070812,
#        0.01070812, 0.01070812, 0.01070812, 0.01056995, 0.04880829,
#        0.04884283, 0.04511226, 0.04500864, 0.01067358, 0.01067358,
#        0.00977547, 0.00977547, 0.38093264, 0.44981002, 0.65354059,
#        0.72556131, 0.7638342 , 0.78583765, 0.80290155, 0.81236615,
#        0.01150259, 0.00238342, 0.01115717, 0.01115717, 0.05357513,
#        0.0074266 , 0.04873921, 0.07678756, 0.01150259, 0.05354059,
#        0.01129534, 0.04511226, 0.25692573, 0.25692573, 0.25692573,
#        0.0056304 , 0.0056304 , 0.0056304 , 0.16117444, 0.1674266 ,
#        0.01067358, 0.01067358, 0.01067358, 0.01067358, 0.01067358,
#        0.01067358, 0.01067358, 0.01067358, 0.01067358, 0.01067358,
#        0.25692573, 0.04877375, 0.01115717, 0.77160622, 0.01050086,
#        0.01050086, 0.01050086, 0.01050086, 0.01050086, 0.01050086,
#        0.01050086, 0.01050086, 0.01050086, 0.01050086, 0.23778929,
#        0.23778929, 0.23778929, 0.23778929, 0.23778929, 0.23778929,
#        0.23778929, 0.23778929, 0.23778929, 0.0451468 , 0.04877375,
#        0.07105354, 0.07105354, 0.07105354, 0.07098446, 0.071019  ,
#        0.071019  , 0.07105354, 0.07108808, 0.01115717, 0.04877375,
#        0.04884283, 0.04884283, 0.04880829, 0.04884283, 0.04884283,
#        0.04880829, 0.04880829, 0.04873921, 0.04877375, 0.04873921,
#        0.04873921, 0.071019  , 0.17360967, 0.16117444, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.01053541,
#        0.01053541, 0.01053541, 0.01053541, 0.01053541, 0.04877375,
#        0.04873921])

# %%
df.isnull().sum()/df.shape[0]
# Out:
# class     0.000000
# aa_000    0.000000
# ab_000    0.771606
# ac_000    0.060380
# ad_000    0.256926
#             ...
# ee_007    0.010535
# ee_008    0.010535
# ee_009    0.010535
# ef_000    0.048774
# eg_000    0.048739
# Length: 171, dtype: float64

# %%
drop_column_names=[]
for column_name,missing_percentage in zip((df.isnull().sum()/df.shape[0]).index,(df.isnull().sum()/df.shape[0]).values):
    print(column_name,missing_percentage*100)
    if missing_percentage>0.3:
        drop_column_names.append(column_name)
# Out:
# class 0.0
# aa_000 0.0
# ab_000 77.16062176165804
# ac_000 6.037996545768567
# ad_000 25.692573402417963
# ae_000 4.500863557858376
# af_000 4.500863557858376
# ag_000 1.0535405872193437
# ag_001 1.0535405872193437
# ag_002 1.0535405872193437
# ag_003 1.0535405872193437
# ag_004 1.0535405872193437
# ag_005 1.0535405872193437
# ag_006 1.0535405872193437
# ag_007 1.0535405872193437
# ag_008 1.0535405872193437
# ag_009 1.0535405872193437
# ah_000 1.0569948186528497
# ai_000 1.0535405872193437
# aj_000 1.0535405872193437
# ak_000 7.76511226252159
# al_000 1.067357512953368
# am_0 1.0535405872193437
# an_000 1.067357512953368
# ao_000 0.9775474956822107
# ap_000 1.067357512953368
# aq_000 0.9775474956822107
# ar_000 4.8739205526770295
# as_000 1.0535405872193437
# at_000 1.0535405872193437
# au_000 1.0535405872193437
# av_000 4.504317789291883
# ax_000 4.507772020725389
# ay_000 1.0535405872193437
# ay_001 1.0535405872193437
# ay_002 1.0535405872193437
# ay_003 1.0535405872193437
# ay_004 1.0535405872193437
# ay_005 1.0535405872193437
# ay_006 1.0535405872193437
# ay_007 1.0535405872193437
# ay_008 1.0535405872193437
# ay_009 1.0535405872193437
# az_000 1.0535405872193437
# az_001 1.0535405872193437
# az_002 1.0535405872193437
# az_003 1.0535405872193437
# az_004 1.0535405872193437
# az_005 1.0535405872193437
# az_006 1.0535405872193437
# az_007 1.0535405872193437
# az_008 1.0535405872193437
# az_009 1.0535405872193437
# ba_000 1.070811744386874
# ba_001 1.070811744386874
# ba_002 1.070811744386874
# ba_003 1.070811744386874
# ba_004 1.070811744386874
# ba_005 1.070811744386874
# ba_006 1.070811744386874
# ba_007 1.070811744386874
# ba_008 1.070811744386874
# ba_009 1.070811744386874
# bb_000 1.0569948186528497
# bc_000 4.880829015544041
# bd_000 4.884283246977548
# be_000 4.511226252158894
# bf_000 4.500863557858376
# bg_000 1.067357512953368
# bh_000 1.067357512953368
# bi_000 0.9775474956822107
# bj_000 0.9775474956822107
# bk_000 38.09326424870466
# bl_000 44.98100172711572
# bm_000 65.35405872193436
# bn_000 72.55613126079447
# bo_000 76.38341968911917
# bp_000 78.58376511226253
# bq_000 80.29015544041451
# br_000 81.23661485319516
# bs_000 1.150259067357513
# bt_000 0.23834196891191708
# bu_000 1.1157167530224525
# bv_000 1.1157167530224525
# bx_000 5.357512953367875
# by_000 0.7426597582037997
# bz_000 4.8739205526770295
# ca_000 7.678756476683938
# cb_000 1.150259067357513
# cc_000 5.354058721934369
# cd_000 1.1295336787564767
# ce_000 4.511226252158894
# cf_000 25.692573402417963
# cg_000 25.692573402417963
# ch_000 25.692573402417963
# ci_000 0.5630397236614854
# cj_000 0.5630397236614854
# ck_000 0.5630397236614854
# cl_000 16.117443868739205
# cm_000 16.7426597582038
# cn_000 1.067357512953368
# cn_001 1.067357512953368
# cn_002 1.067357512953368
# cn_003 1.067357512953368
# cn_004 1.067357512953368
# cn_005 1.067357512953368
# cn_006 1.067357512953368
# cn_007 1.067357512953368
# cn_008 1.067357512953368
# cn_009 1.067357512953368
# co_000 25.692573402417963
# cp_000 4.877374784110535
# cq_000 1.1157167530224525
# cr_000 77.16062176165804
# cs_000 1.0500863557858378
# cs_001 1.0500863557858378
# cs_002 1.0500863557858378
# cs_003 1.0500863557858378
# cs_004 1.0500863557858378
# cs_005 1.0500863557858378
# cs_006 1.0500863557858378
# cs_007 1.0500863557858378
# cs_008 1.0500863557858378
# cs_009 1.0500863557858378
# ct_000 23.778929188255614
# cu_000 23.778929188255614
# cv_000 23.778929188255614
# cx_000 23.778929188255614
# cy_000 23.778929188255614
# cz_000 23.778929188255614
# da_000 23.778929188255614
# db_000 23.778929188255614
# dc_000 23.778929188255614
# dd_000 4.514680483592401
# de_000 4.877374784110535
# df_000 7.105354058721934
# dg_000 7.105354058721934
# dh_000 7.105354058721934
# di_000 7.098445595854923
# dj_000 7.101899827288428
# dk_000 7.101899827288428
# dl_000 7.105354058721934
# dm_000 7.10880829015544
# dn_000 1.1157167530224525
# do_000 4.877374784110535
# dp_000 4.884283246977548
# dq_000 4.884283246977548
# dr_000 4.880829015544041
# ds_000 4.884283246977548
# dt_000 4.884283246977548
# du_000 4.880829015544041
# dv_000 4.880829015544041
# dx_000 4.8739205526770295
# dy_000 4.877374784110535
# dz_000 4.8739205526770295
# ea_000 4.8739205526770295
# eb_000 7.101899827288428
# ec_00 17.360967184801382
# ed_000 16.117443868739205
# ee_000 1.0535405872193437
# ee_001 1.0535405872193437
# ee_002 1.0535405872193437
# ee_003 1.0535405872193437
# ee_004 1.0535405872193437
# ee_005 1.0535405872193437
# ee_006 1.0535405872193437
# ee_007 1.0535405872193437
# ee_008 1.0535405872193437
# ee_009 1.0535405872193437
# ef_000 4.877374784110535
# eg_000 4.8739205526770295

# %%
drop_column_names
# Out:
# ['ab_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'cr_000']

# %%
df.isna().sum()/df.shape[0]>0.03
# Out:
# class     False
# aa_000    False
# ab_000     True
# ac_000    False
# ad_000    False
#           ...
# ee_007    False
# ee_008    False
# ee_009    False
# ef_000    False
# eg_000    False
# Length: 171, dtype: bool

# %%
null_report=df.isna().sum()/df.shape[0]
null_report[null_report>0.3].index

# %%
null_report[null_report>0.3].index
# Out:
# Index(['ab_000', 'bk_000', 'bl_000', 'bm_000', 'bn_000', 'bo_000', 'bp_000',
#        'bq_000', 'br_000', 'cr_000'],
#       dtype='object')

# %%
df.iloc[:,[0]].drop("class",axis=1).columns
# Out:
# Index([], dtype='object')

# %%
len(df.iloc[:,[0]].drop("class",axis=1).columns)
# Out:
# 0
